# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, UpSampling2D, BatchNormalization, SpatialDropout2D, Input, MaxPool2D, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.applications import vgg16
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.data import Dataset, AUTOTUNE
import tensorflow.strings
from tensorflow.keras.utils import plot_model

import matplotlib.pyplot as plt

from glob import glob
from pathlib import Path
import os

# %%
PATH_TO_TRAINING = r'/content/drive/My Drive/Drishti/Training-20211018T055246Z-001/Training'
PATH_TO_TRAINING_TENSOR = tf.Variable(PATH_TO_TRAINING)

TRAIN_GLAUCOMA_IMAGES = np.array(glob(os.path.join(PATH_TO_TRAINING, 'Images/GLAUCOMA/*')))
TRAIN_NORMAL_IMAGES = np.array(glob(os.path.join(PATH_TO_TRAINING, 'Images/NORMAL/*')))

TRAIN_GLAUCOMA_GT = np.array(glob(PATH_TO_TRAINING + '/GT/GALUCOMA/*'))
TRAIN_NORMAL_GT = np.array(glob(PATH_TO_TRAINING + '/GT/NORMAL/*'))

PATH_TO_TEST = r'/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test'
TEST_GLAUCOMA_IMAGES = np.array(glob(os.path.join(PATH_TO_TEST, 'Images/glaucoma/*')))
TEST_NORMAL_IMAGES = np.array(glob(os.path.join(PATH_TO_TEST, 'Images/normal/*')))

SEED = 2
EPSILON = 10 ** -4
STATELESS_RNG= tf.random.Generator.from_seed(SEED, alg='philox')
IMAGE_SIZE = (224, 224)
CHANNELS = 3
SHUFFLE_BUFFER = len(TRAIN_NORMAL_IMAGES) + len(TRAIN_GLAUCOMA_IMAGES)
BATCH_SIZE = SHUFFLE_BUFFER // 2
early_stopping = EarlyStopping(monitor = 'val_loss', restore_best_weights = True, patience = 5)

# %%
Path(TRAIN_GLAUCOMA_IMAGES[0]).stem
TEST_GLAUCOMA_IMAGES
# Out:
# array(['/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_003.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_001.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_021.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_006.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_005.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_029.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_011.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_027.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_025.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_028.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_023.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_019.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_020.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_014.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_039.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_055.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_056.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_065.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_048.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_053.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_071.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_073.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_052.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_030.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_067.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_034.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_070.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_054.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_074.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_043.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_059.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_050.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_087.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_083.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_086.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_079.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_077.png',
#        '/content/drive/My Drive/Drishti/Test-20211018T060000Z-001/Test/Images/glaucoma/drishtiGS_082.png'],
#       dtype='<U96')

# %%
def load_image_and_gt(path, test = False):
    '''
    Takes a path to the image,
    and returns the image alongside
    its ground truth
    '''

    print(path)

    filename = Path(path).stem
    if test:
        path_to_OD_softmap = os.path.join(PATH_TO_TEST, 'Test_GT', filename, 'SoftMap', filename + '_ODsegSoftmap.png')
        path_to_cup_softmap = os.path.join(PATH_TO_TEST, 'Test_GT', filename, 'SoftMap', filename + '_cupsegSoftmap.png')
    else:
        path_to_OD_softmap = os.path.join(PATH_TO_TRAINING, 'GT', filename, 'SoftMap', filename + '_ODsegSoftmap.png')
        path_to_cup_softmap = os.path.join(PATH_TO_TRAINING, 'GT', filename, 'SoftMap', filename + '_cupsegSoftmap.png')
    image = tf.io.read_file(path)
    image = tf.io.decode_png(image)
    od = tf.io.read_file(path_to_OD_softmap)
    od = tf.io.decode_png(od)
    cup = tf.io.read_file(path_to_cup_softmap)
    cup = tf.io.decode_png(cup)
    return image, od, cup

def show_image_with_masks(image, od, cup, ax, index, label):
    '''
    Plots the real world image
    And the two masks
    Also shows the image after
    being masked with each mask
    Requires len(ax) >= 5
    '''
    ax[5 * index].imshow(image)
    ax[5 * index].set_title(label)
    ax[5 * index + 1].imshow(od)
    ax[5 * index + 1].set_title('Optical Disk Mask')
    ax[5 * index + 2].imshow(od * image)
    ax[5 * index + 2].set_title('Image with OD Mask')
    ax[5 * index + 3].imshow(cup)
    ax[5 * index + 3].set_title('Cup Mask')
    ax[5 * index + 4].imshow(cup * image)
    ax[5 * index + 4].set_title('Image with CUP Mask')

def load_image_with_masks(path, dice = False, test = False):
    '''
    This is similar to the
    load image_with_gt function
    however uses pure tf functions
    for the use in datasets
    otherwise I'd have to run
    in eagerexecution
    '''

    filename = tf.strings.split(path, sep = '.')[-2]
    filename = tf.strings.split(filename, sep = '/')[-1]
    directory_path = tf.strings.split(path, sep = 'Images')[0]
    if test:
        softmap_path = tf.strings.join([directory_path, 'Test_GT/', filename, '/SoftMap/'])
    else:
        softmap_path = tf.strings.join([directory_path, 'GT/', filename, '/SoftMap/'])
    od_path = tf.strings.join([softmap_path, filename, '_ODsegSoftmap.png'])
    cup_path = tf.strings.join([softmap_path, filename, '_cupsegSoftmap.png'])
    image = tf.io.read_file(path)
    image = tf.io.decode_png(image, channels = 3)
    image = tf.image.resize(image, IMAGE_SIZE)
    image = image / 255.0

    od = tf.io.read_file(od_path)
    od = tf.io.decode_png(od, channels = 1)
    od = tf.image.resize(od, IMAGE_SIZE)
    od = od / 255.0
    if dice:
        od = tf.where(od >= 0.5, 1.0, 0.0)

    cup = tf.io.read_file(cup_path)
    cup = tf.io.decode_png(cup, channels = 1)
    cup = tf.image.resize(cup, IMAGE_SIZE)
    cup = cup / 255.0
    if dice:
        cup = tf.where(cup >= 0.5, 1.0, 0.0)

    return {'image' : image}, {'od' : od, 'cup' : cup}

def augment_images(image, od, cup, single_target = False):

    seeds = STATELESS_RNG.make_seeds(2)[0], STATELESS_RNG.make_seeds(2)[0]

    def augment(img, seeds):

        img = tf.image.stateless_random_flip_left_right(img, seeds[0])
        img = tf.image.stateless_random_flip_up_down(img, seeds[1])
        img = tf.image.resize_with_crop_or_pad(img, IMAGE_SIZE[0] + 20, IMAGE_SIZE[1] + 20)
        img = tf.image.stateless_random_crop(img, size = (*IMAGE_SIZE, img.shape[2]), seed = seeds[0])

        return img

    image = augment(image, seeds)
    od = augment(od, seeds)
    cup = augment(cup, seeds)

    if single_target:
        return image, od
    return {'image' : image}, {'od' : od, 'cup' : cup}

# %%
image, od, cup = load_image_and_gt(TRAIN_NORMAL_IMAGES[0])
plt.imshow(od)
image.shape
# Out:
# /content/drive/My Drive/Drishti/Training-20211018T055246Z-001/Training/Images/NORMAL/drishtiGS_008.png
# TensorShape([1755, 2049, 3])

# %%
rows = 6
cols = 5
fig, axes = plt.subplots(rows, cols, figsize = (15, 15))
axes = axes.flatten()

normal_images = np.random.choice(TRAIN_NORMAL_IMAGES, rows // 2)
glaucoma_images = np.random.choice(TRAIN_GLAUCOMA_IMAGES, rows - (rows // 2))

for idx, file in enumerate(normal_images):
    image, od, cup = load_image_and_gt(file)
    show_image_with_masks(image, od, cup, axes, index = idx, label = 'Normal :' + os.path.basename(file))

for idx, file in enumerate(glaucoma_images):
    image, od, cup = load_image_and_gt(file)
    show_image_with_masks(image, od, cup, axes, index = idx + rows // 2, label = 'Glaucoma :' + os.path.basename(file))

plt.tight_layout()
# Out:
# /content/drive/My Drive/Drishti/Training-20211018T055246Z-001/Training/Images/NORMAL/drishtiGS_008.png
# /content/drive/My Drive/Drishti/Training-20211018T055246Z-001/Training/Images/NORMAL/drishtiGS_008.png
# /content/drive/My Drive/Drishti/Training-20211018T055246Z-001/Training/Images/NORMAL/drishtiGS_090.png
# /content/drive/My Drive/Drishti/Training-20211018T055246Z-001/Training/Images/GLAUCOMA/drishtiGS_002.png
# /content/drive/My Drive/Drishti/Training-20211018T055246Z-001/Training/Images/GLAUCOMA/drishtiGS_076.png
# /content/drive/My Drive/Drishti/Training-20211018T055246Z-001/Training/Images/GLAUCOMA/drishtiGS_049.png

# %%
def get_avgboundary(file):
    image = tf.io.read_file(file)
    image = tf.io.decode_png(image)

    cup_mask = np.zeros(shape = (image.shape[0], image.shape[1]))
    od_mask = np.zeros(shape = (image.shape[0], image.shape[1]))
    center_mask = np.zeros(shape = (image.shape[0], image.shape[1]))

    filename = Path(file).stem
    boundary_path = os.path.join(PATH_TO_TRAINING, 'GT', filename, 'AvgBoundary')
    cup_file = os.path.join(boundary_path, filename + '_CupAvgBoundary.txt')
    od_file = os.path.join(boundary_path, filename + '_ODAvgBoundary.txt')
    center_file = os.path.join(boundary_path, filename + '_diskCenter.txt')

    count = 0
    with open(cup_file) as cf:
        for line in cf:
            a, b = line.split()
            a = int(a)
            b = int(b)
            cup_mask[a, b] = 255
            count += 1

    with open(od_file) as of:
        for line in of:
            a, b = line.split()
            a = int(a)
            b = int(b)
            od_mask[a, b] = 255

    with open(center_file) as ctrf:
        for line in ctrf:
            a, b = line.split()
            a = int(a)
            b = int(b)
            center_mask[a, b] = 255
    return od_mask.reshape(image.shape[0], image.shape[1], 1), \
cup_mask.reshape(image.shape[0], image.shape[1], 1), center_mask.reshape(image.shape[0], image.shape[1], 1)

# %%
glaucoma_avgboundary_test = TRAIN_GLAUCOMA_IMAGES[3]

od_mask, cup_mask, center_mask = get_avgboundary(glaucoma_avgboundary_test)
image, od, cup = load_image_and_gt(glaucoma_avgboundary_test)
# Out:
# /content/drive/My Drive/Drishti/Training-20211018T055246Z-001/Training/Images/GLAUCOMA/drishtiGS_024.png

# %%
fig, axes = plt.subplots(2, 3, figsize = (20, 20))
axes = axes.flatten()

axes[0].imshow(image)
axes[0].set_title('Test Image')
axes[1].imshow(od)
axes[1].set_title('Optical Disk Mask')
axes[2].imshow(od_mask)
axes[2].set_title('Optical Disk Avg Boundary')
axes[3].imshow(cup)
axes[3].set_title('Cup Mask')
axes[4].imshow(cup_mask)
axes[4].set_title('Cup Avg Boundary')
axes[5].imshow(center_mask)
axes[5].set_title('Center Avg Boundary')
plt.tight_layout()

# %%
train_images = np.concatenate([TRAIN_NORMAL_IMAGES, TRAIN_GLAUCOMA_IMAGES])
test_images = np.concatenate([TEST_NORMAL_IMAGES, TEST_GLAUCOMA_IMAGES])

train_ds_dice = Dataset.from_tensor_slices(train_images)\
    .shuffle(buffer_size = SHUFFLE_BUFFER)\
    .map(lambda x: load_image_with_masks(x, dice = True), num_parallel_calls = AUTOTUNE)\
    .map(lambda image, targets: augment_images(image['image'], targets['od'], targets['cup']))\
    .batch(batch_size = BATCH_SIZE)\
    .prefetch(1)\
    .cache()

train_ds_no_dice = Dataset.from_tensor_slices(train_images)\
    .shuffle(buffer_size = SHUFFLE_BUFFER)\
    .map(lambda x: load_image_with_masks(x, dice = False), num_parallel_calls = AUTOTUNE)\
    .map(lambda image, targets: augment_images(image['image'], targets['od'], targets['cup']))\
    .batch(batch_size = BATCH_SIZE)\
    .prefetch(1)\
    .cache()

test_ds_dice = Dataset.from_tensor_slices(test_images)\
    .map(lambda x: load_image_with_masks(x, dice = True, test = True), num_parallel_calls = AUTOTUNE)\
    .batch(batch_size = BATCH_SIZE)

test_ds_no_dice = Dataset.from_tensor_slices(test_images)\
    .map(lambda x: load_image_with_masks(x, dice = False, test = True), num_parallel_calls = AUTOTUNE)\
    .batch(batch_size = BATCH_SIZE)

# %%
train_ds_no_dice_st = Dataset.from_tensor_slices(train_images)\
    .shuffle(buffer_size = SHUFFLE_BUFFER)\
    .map(lambda x: load_image_with_masks(x, dice = False), num_parallel_calls = AUTOTUNE)\
    .map(lambda image, targets: augment_images(image['image'], targets['od'], targets['cup'], single_target = True))\
    .batch(batch_size = BATCH_SIZE)\
    .prefetch(1)\
    .cache()

test_ds_no_dice_st = Dataset.from_tensor_slices(test_images)\
    .map(lambda x: load_image_with_masks(x, dice = False, test = True), num_parallel_calls = AUTOTUNE)\
    .map(lambda image, targets: (image['image'], targets['od']))\
    .batch(batch_size = BATCH_SIZE)

# %%
def upsampling_block(inp, skips, filters, kernels, rates):
    '''
    Creates a block for upsampling
    Doubles the image dimensions
    And adds the skip connection
    '''
    activation = 'relu'
    x = inp
    for f, kernel, skip, rate in zip(filters, kernels, skips, rates):
        x = UpSampling2D()(x)
        x = Conv2D(filters = f, kernel_size = kernel, strides = 1, activation = activation, padding = 'same')(x)
        x = concatenate([x, skip])
        x = BatchNormalization()(x)
        x = SpatialDropout2D(rate = rate)(x)
    return x

def conv_block(inp, filters, kernels, strides, rates):
    '''
    Builds a convulitional block
    When the strides reach 2
    Keeps the output of the last
    Conv layer to be used
    For a skip connection
    '''

    activation = 'relu'
    x = inp
    skips = []
    for f, kernel, stride, rate in zip(filters, kernels, strides, rates):
        if stride == 2:
            skips.append(skip)
            x = MaxPool2D()(x)
            x = Conv2D(filters = f, kernel_size = kernel, strides = 1, activation = activation, padding = 'same')(x)
            skip = x
        else:
            x = Conv2D(filters = f, kernel_size = kernel, strides = 1, activation = activation, padding = 'same')(x)
            skip = x

        x = BatchNormalization()(x)
        x = SpatialDropout2D(rate = rate)(x)

    return skips, x

# %%
def res_unet(conv_filters, conv_kernels, conv_strides, conv_rates, up_filters, up_kernels, up_rates):
    '''
    Builds the u-net structure
    The output is two heads
    One for the Optical Disk
    And another for the cup
    '''
    inp = Input(shape = (*IMAGE_SIZE, 3), name = 'image')
    x = inp

    skips, x = conv_block(x, conv_filters, conv_kernels, conv_strides, conv_rates)

    skips = skips[::-1]

    od = upsampling_block(x, skips, up_filters, up_kernels, up_rates)
    od = Conv2D(filters = 1, kernel_size = 1, strides = 1, padding = 'same', activation = 'sigmoid', name = 'od')(od)

    cup = upsampling_block(x, skips, up_filters, up_kernels, up_rates)
    cup = Conv2D(filters = 1, kernel_size = 1, strides = 1, padding = 'same', activation = 'sigmoid', name = 'cup')(cup)

    return Model(inputs = inp, outputs = [od, cup])

# %%
def dice(y, y_pred):
    '''
    Dice Loss, similar to
    Intersection over Union
    '''
    epsilon = EPSILON
    numerator = 2 * tf.reduce_sum(y * y_pred, axis = [1, 2])
    denominator = tf.reduce_sum(y + y_pred, axis = [1, 2])
    dice = tf.reduce_mean((numerator + epsilon)/(denominator + epsilon))
    return 1 - dice

# %%
conv_filters = [8, 16, 32, 64]
conv_kernels = [3, 3, 3, 3]
conv_strides = [1, 2, 2, 2]
conv_rates = [0.8, 0.8, 0.8, 0.8]

upsampling_filters = [32, 16, 8, 8]
upsampling_kernels = [3, 3, 3, 3]
upsampling_rates = [0.5, 0.5, 0.5, 0.5]

mod1 = res_unet(conv_filters, conv_kernels, conv_strides, conv_rates, upsampling_filters, upsampling_kernels, upsampling_rates)
mod1.compile(optimizer = 'Adam', loss = {'od' : dice, 'cup' : dice}, metrics = ['accuracy'])

# %%
plot_model(mod1)

# %%
hist1 = mod1.fit(train_ds_dice, validation_data = test_ds_dice, callbacks = [early_stopping], epochs = 200)
# Out:
# Epoch 1/200
# 2/2 [==============================] - 147s 98s/step - loss: 1.9157 - od_loss: 0.9358 - cup_loss: 0.9799 - od_accuracy: 0.4474 - cup_accuracy: 0.4950 - val_loss: 1.9068 - val_od_loss: 0.9388 - val_cup_loss: 0.9680 - val_od_accuracy: 0.2560 - val_cup_accuracy: 0.9065
# Epoch 2/200
# 2/2 [==============================] - 28s 20s/step - loss: 1.9082 - od_loss: 0.9286 - cup_loss: 0.9796 - od_accuracy: 0.4881 - cup_accuracy: 0.4834 - val_loss: 1.9060 - val_od_loss: 0.9382 - val_cup_loss: 0.9678 - val_od_accuracy: 0.3123 - val_cup_accuracy: 0.8759
# Epoch 3/200
# 2/2 [==============================] - 26s 17s/step - loss: 1.9121 - od_loss: 0.9323 - cup_loss: 0.9799 - od_accuracy: 0.4668 - cup_accuracy: 0.5181 - val_loss: 1.9054 - val_od_loss: 0.9378 - val_cup_loss: 0.9676 - val_od_accuracy: 0.3296 - val_cup_accuracy: 0.7974
# Epoch 4/200
# 2/2 [==============================] - 27s 17s/step - loss: 1.9085 - od_loss: 0.9283 - cup_loss: 0.9802 - od_accuracy: 0.5723 - cup_accuracy: 0.4382 - val_loss: 1.9049 - val_od_loss: 0.9375 - val_cup_loss: 0.9674 - val_od_accuracy: 0.3411 - val_cup_accuracy: 0.4358
# Epoch 5/200
# 2/2 [==============================] - 28s 18s/step - loss: 1.9081 - od_loss: 0.9310 - cup_loss: 0.9771 - od_accuracy: 0.5582 - cup_accuracy: 0.4862 - val_loss: 1.9043 - val_od_loss: 0.9372 - val_cup_loss: 0.9671 - val_od_accuracy: 0.3872 - val_cup_accuracy: 0.1608
# Epoch 6/200
# 2/2 [==============================] - 26s 18s/step - loss: 1.8981 - od_loss: 0.9218 - cup_loss: 0.9763 - od_accuracy: 0.5820 - cup_accuracy: 0.4479 - val_loss: 1.9037 - val_od_loss: 0.9368 - val_cup_loss: 0.9669 - val_od_accuracy: 0.4516 - val_cup_accuracy: 0.0358
# Epoch 7/200
# 2/2 [==============================] - 28s 19s/step - loss: 1.8971 - od_loss: 0.9201 - cup_loss: 0.9769 - od_accuracy: 0.5404 - cup_accuracy: 0.4293 - val_loss: 1.9032 - val_od_loss: 0.9365 - val_cup_loss: 0.9667 - val_od_accuracy: 0.5293 - val_cup_accuracy: 0.0199
# Epoch 8/200
# 2/2 [==============================] - 27s 17s/step - loss: 1.9055 - od_loss: 0.9282 - cup_loss: 0.9773 - od_accuracy: 0.5690 - cup_accuracy: 0.4844 - val_loss: 1.9025 - val_od_loss: 0.9362 - val_cup_loss: 0.9663 - val_od_accuracy: 0.5652 - val_cup_accuracy: 0.0204
# Epoch 9/200
# 2/2 [==============================] - 27s 18s/step - loss: 1.8832 - od_loss: 0.9062 - cup_loss: 0.9770 - od_accuracy: 0.5269 - cup_accuracy: 0.4758 - val_loss: 1.9016 - val_od_loss: 0.9356 - val_cup_loss: 0.9660 - val_od_accuracy: 0.6555 - val_cup_accuracy: 0.0197
# Epoch 10/200
# 2/2 [==============================] - 27s 18s/step - loss: 1.8970 - od_loss: 0.9248 - cup_loss: 0.9723 - od_accuracy: 0.4836 - cup_accuracy: 0.4943 - val_loss: 1.9006 - val_od_loss: 0.9350 - val_cup_loss: 0.9656 - val_od_accuracy: 0.7101 - val_cup_accuracy: 0.0192
# Epoch 11/200
# 2/2 [==============================] - 27s 19s/step - loss: 1.8784 - od_loss: 0.9108 - cup_loss: 0.9676 - od_accuracy: 0.5775 - cup_accuracy: 0.5097 - val_loss: 1.8995 - val_od_loss: 0.9344 - val_cup_loss: 0.9651 - val_od_accuracy: 0.7731 - val_cup_accuracy: 0.0201
# Epoch 12/200
# 2/2 [==============================] - 27s 20s/step - loss: 1.8880 - od_loss: 0.9189 - cup_loss: 0.9690 - od_accuracy: 0.5335 - cup_accuracy: 0.4692 - val_loss: 1.8985 - val_od_loss: 0.9339 - val_cup_loss: 0.9646 - val_od_accuracy: 0.8012 - val_cup_accuracy: 0.0283
# Epoch 13/200
# 2/2 [==============================] - 28s 20s/step - loss: 1.8807 - od_loss: 0.9144 - cup_loss: 0.9663 - od_accuracy: 0.6016 - cup_accuracy: 0.4437 - val_loss: 1.8975 - val_od_loss: 0.9334 - val_cup_loss: 0.9641 - val_od_accuracy: 0.8244 - val_cup_accuracy: 0.1141
# Epoch 14/200
# 2/2 [==============================] - 28s 19s/step - loss: 1.8768 - od_loss: 0.9157 - cup_loss: 0.9611 - od_accuracy: 0.5960 - cup_accuracy: 0.5180 - val_loss: 1.8966 - val_od_loss: 0.9330 - val_cup_loss: 0.9636 - val_od_accuracy: 0.8314 - val_cup_accuracy: 0.1622
# Epoch 15/200
# 2/2 [==============================] - 27s 18s/step - loss: 1.8801 - od_loss: 0.9161 - cup_loss: 0.9640 - od_accuracy: 0.5699 - cup_accuracy: 0.4914 - val_loss: 1.8958 - val_od_loss: 0.9326 - val_cup_loss: 0.9632 - val_od_accuracy: 0.8518 - val_cup_accuracy: 0.2164
# Epoch 16/200
# 2/2 [==============================] - 27s 18s/step - loss: 1.8691 - od_loss: 0.9072 - cup_loss: 0.9619 - od_accuracy: 0.5977 - cup_accuracy: 0.4812 - val_loss: 1.8948 - val_od_loss: 0.9323 - val_cup_loss: 0.9626 - val_od_accuracy: 0.8698 - val_cup_accuracy: 0.3435
# Epoch 17/200
# 2/2 [==============================] - 27s 19s/step - loss: 1.8772 - od_loss: 0.9151 - cup_loss: 0.9620 - od_accuracy: 0.5560 - cup_accuracy: 0.5008 - val_loss: 1.8939 - val_od_loss: 0.9318 - val_cup_loss: 0.9621 - val_od_accuracy: 0.8825 - val_cup_accuracy: 0.4756
# Epoch 18/200
# 2/2 [==============================] - 27s 20s/step - loss: 1.8754 - od_loss: 0.9094 - cup_loss: 0.9660 - od_accuracy: 0.6181 - cup_accuracy: 0.5090 - val_loss: 1.8931 - val_od_loss: 0.9313 - val_cup_loss: 0.9618 - val_od_accuracy: 0.9057 - val_cup_accuracy: 0.5524
# Epoch 19/200
# 2/2 [==============================] - 37s 28s/step - loss: 1.8634 - od_loss: 0.9036 - cup_loss: 0.9598 - od_accuracy: 0.5919 - cup_accuracy: 0.4783 - val_loss: 1.8921 - val_od_loss: 0.9307 - val_cup_loss: 0.9614 - val_od_accuracy: 0.9330 - val_cup_accuracy: 0.6494
# Epoch 20/200
# 2/2 [==============================] - 28s 20s/step - loss: 1.8649 - od_loss: 0.9038 - cup_loss: 0.9611 - od_accuracy: 0.5759 - cup_accuracy: 0.4685 - val_loss: 1.8912 - val_od_loss: 0.9303 - val_cup_loss: 0.9609 - val_od_accuracy: 0.9385 - val_cup_accuracy: 0.7612
# Epoch 21/200
# 2/2 [==============================] - 27s 20s/step - loss: 1.8516 - od_loss: 0.8970 - cup_loss: 0.9546 - od_accuracy: 0.6421 - cup_accuracy: 0.5089 - val_loss: 1.8900 - val_od_loss: 0.9297 - val_cup_loss: 0.9603 - val_od_accuracy: 0.9546 - val_cup_accuracy: 0.8579
# Epoch 22/200
# 2/2 [==============================] - 27s 20s/step - loss: 1.8566 - od_loss: 0.8971 - cup_loss: 0.9595 - od_accuracy: 0.6212 - cup_accuracy: 0.5238 - val_loss: 1.8890 - val_od_loss: 0.9291 - val_cup_loss: 0.9599 - val_od_accuracy: 0.9635 - val_cup_accuracy: 0.9084
# Epoch 23/200
# 2/2 [==============================] - 26s 18s/step - loss: 1.8479 - od_loss: 0.8946 - cup_loss: 0.9532 - od_accuracy: 0.6445 - cup_accuracy: 0.5274 - val_loss: 1.8880 - val_od_loss: 0.9284 - val_cup_loss: 0.9595 - val_od_accuracy: 0.9734 - val_cup_accuracy: 0.9399
# Epoch 24/200
# 2/2 [==============================] - 28s 20s/step - loss: 1.8541 - od_loss: 0.8960 - cup_loss: 0.9581 - od_accuracy: 0.6344 - cup_accuracy: 0.4874 - val_loss: 1.8870 - val_od_loss: 0.9278 - val_cup_loss: 0.9592 - val_od_accuracy: 0.9767 - val_cup_accuracy: 0.9499
# Epoch 25/200
# 2/2 [==============================] - 28s 20s/step - loss: 1.8456 - od_loss: 0.8986 - cup_loss: 0.9470 - od_accuracy: 0.6063 - cup_accuracy: 0.5430 - val_loss: 1.8859 - val_od_loss: 0.9271 - val_cup_loss: 0.9588 - val_od_accuracy: 0.9773 - val_cup_accuracy: 0.9511
# Epoch 26/200
# 2/2 [==============================] - 28s 19s/step - loss: 1.8669 - od_loss: 0.9092 - cup_loss: 0.9577 - od_accuracy: 0.5694 - cup_accuracy: 0.5449 - val_loss: 1.8849 - val_od_loss: 0.9264 - val_cup_loss: 0.9585 - val_od_accuracy: 0.9769 - val_cup_accuracy: 0.9537
# Epoch 27/200
# 2/2 [==============================] - 28s 19s/step - loss: 1.8559 - od_loss: 0.8995 - cup_loss: 0.9564 - od_accuracy: 0.6245 - cup_accuracy: 0.6140 - val_loss: 1.8839 - val_od_loss: 0.9258 - val_cup_loss: 0.9581 - val_od_accuracy: 0.9759 - val_cup_accuracy: 0.9658
# Epoch 28/200
# 2/2 [==============================] - 28s 18s/step - loss: 1.8298 - od_loss: 0.8849 - cup_loss: 0.9449 - od_accuracy: 0.6564 - cup_accuracy: 0.5406 - val_loss: 1.8829 - val_od_loss: 0.9253 - val_cup_loss: 0.9576 - val_od_accuracy: 0.9743 - val_cup_accuracy: 0.9723
# Epoch 29/200
# 2/2 [==============================] - 27s 18s/step - loss: 1.8071 - od_loss: 0.8713 - cup_loss: 0.9359 - od_accuracy: 0.6234 - cup_accuracy: 0.4976 - val_loss: 1.8820 - val_od_loss: 0.9250 - val_cup_loss: 0.9570 - val_od_accuracy: 0.9732 - val_cup_accuracy: 0.9743
# Epoch 30/200
# 2/2 [==============================] - 27s 18s/step - loss: 1.8524 - od_loss: 0.9006 - cup_loss: 0.9518 - od_accuracy: 0.6743 - cup_accuracy: 0.5511 - val_loss: 1.8812 - val_od_loss: 0.9247 - val_cup_loss: 0.9565 - val_od_accuracy: 0.9721 - val_cup_accuracy: 0.9762
# Epoch 31/200
# 2/2 [==============================] - 27s 20s/step - loss: 1.8267 - od_loss: 0.8787 - cup_loss: 0.9480 - od_accuracy: 0.6219 - cup_accuracy: 0.6020 - val_loss: 1.8806 - val_od_loss: 0.9246 - val_cup_loss: 0.9560 - val_od_accuracy: 0.9712 - val_cup_accuracy: 0.9777
# Epoch 32/200
# 2/2 [==============================] - 27s 20s/step - loss: 1.8284 - od_loss: 0.8812 - cup_loss: 0.9472 - od_accuracy: 0.6668 - cup_accuracy: 0.5152 - val_loss: 1.8803 - val_od_loss: 0.9246 - val_cup_loss: 0.9557 - val_od_accuracy: 0.9704 - val_cup_accuracy: 0.9771
# Epoch 33/200
# 2/2 [==============================] - 27s 20s/step - loss: 1.8432 - od_loss: 0.8889 - cup_loss: 0.9543 - od_accuracy: 0.6872 - cup_accuracy: 0.5225 - val_loss: 1.8800 - val_od_loss: 0.9246 - val_cup_loss: 0.9554 - val_od_accuracy: 0.9697 - val_cup_accuracy: 0.9738
# Epoch 34/200
# 2/2 [==============================] - 25s 17s/step - loss: 1.8266 - od_loss: 0.8881 - cup_loss: 0.9386 - od_accuracy: 0.6609 - cup_accuracy: 0.5873 - val_loss: 1.8799 - val_od_loss: 0.9248 - val_cup_loss: 0.9551 - val_od_accuracy: 0.9691 - val_cup_accuracy: 0.9739
# Epoch 35/200
# 2/2 [==============================] - 36s 29s/step - loss: 1.8019 - od_loss: 0.8770 - cup_loss: 0.9249 - od_accuracy: 0.6432 - cup_accuracy: 0.5242 - val_loss: 1.8801 - val_od_loss: 0.9252 - val_cup_loss: 0.9548 - val_od_accuracy: 0.9688 - val_cup_accuracy: 0.9775
# Epoch 36/200
# 2/2 [==============================] - 28s 18s/step - loss: 1.8212 - od_loss: 0.8853 - cup_loss: 0.9359 - od_accuracy: 0.6858 - cup_accuracy: 0.5554 - val_loss: 1.8806 - val_od_loss: 0.9260 - val_cup_loss: 0.9546 - val_od_accuracy: 0.9685 - val_cup_accuracy: 0.9802
# Epoch 37/200
# 2/2 [==============================] - 27s 20s/step - loss: 1.8168 - od_loss: 0.8745 - cup_loss: 0.9424 - od_accuracy: 0.6046 - cup_accuracy: 0.5531 - val_loss: 1.8810 - val_od_loss: 0.9267 - val_cup_loss: 0.9543 - val_od_accuracy: 0.9683 - val_cup_accuracy: 0.9813
# Epoch 38/200
# 2/2 [==============================] - 27s 20s/step - loss: 1.8176 - od_loss: 0.8755 - cup_loss: 0.9421 - od_accuracy: 0.6776 - cup_accuracy: 0.5617 - val_loss: 1.8811 - val_od_loss: 0.9274 - val_cup_loss: 0.9538 - val_od_accuracy: 0.9683 - val_cup_accuracy: 0.9807
# Epoch 39/200
# 2/2 [==============================] - 27s 20s/step - loss: 1.8092 - od_loss: 0.8725 - cup_loss: 0.9366 - od_accuracy: 0.6836 - cup_accuracy: 0.5596 - val_loss: 1.8807 - val_od_loss: 0.9275 - val_cup_loss: 0.9531 - val_od_accuracy: 0.9683 - val_cup_accuracy: 0.9773

# %%
mod2 = res_unet(conv_filters, conv_kernels, conv_strides, conv_rates, upsampling_filters, upsampling_kernels, upsampling_rates)
mod2.compile(optimizer = 'Adam', loss = {'od' : 'binary_crossentropy', 'cup' : 'binary_crossentropy'}, metrics = ['accuracy'])
hist2 = mod2.fit(train_ds_no_dice, validation_data = test_ds_no_dice, callbacks = [early_stopping], epochs = 100)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 57s 21s/step - loss: 1.7584 - od_loss: 0.9038 - cup_loss: 0.8546 - od_accuracy: 0.5505 - cup_accuracy: 0.5089 - val_loss: 1.3897 - val_od_loss: 0.7186 - val_cup_loss: 0.6710 - val_od_accuracy: 0.1980 - val_cup_accuracy: 0.9143
# Epoch 2/100
# 2/2 [==============================] - 39s 24s/step - loss: 1.8129 - od_loss: 0.9512 - cup_loss: 0.8617 - od_accuracy: 0.5490 - cup_accuracy: 0.5782 - val_loss: 1.3792 - val_od_loss: 0.7132 - val_cup_loss: 0.6661 - val_od_accuracy: 0.2220 - val_cup_accuracy: 0.9475
# Epoch 3/100
# 2/2 [==============================] - 28s 21s/step - loss: 1.8033 - od_loss: 0.8770 - cup_loss: 0.9263 - od_accuracy: 0.6032 - cup_accuracy: 0.5363 - val_loss: 1.3639 - val_od_loss: 0.7073 - val_cup_loss: 0.6565 - val_od_accuracy: 0.2661 - val_cup_accuracy: 0.9699
# Epoch 4/100
# 2/2 [==============================] - 25s 17s/step - loss: 1.6960 - od_loss: 0.8610 - cup_loss: 0.8351 - od_accuracy: 0.5811 - cup_accuracy: 0.5851 - val_loss: 1.3478 - val_od_loss: 0.6993 - val_cup_loss: 0.6485 - val_od_accuracy: 0.3734 - val_cup_accuracy: 0.9762
# Epoch 5/100
# 2/2 [==============================] - 31s 20s/step - loss: 1.7090 - od_loss: 0.8574 - cup_loss: 0.8516 - od_accuracy: 0.5859 - cup_accuracy: 0.5644 - val_loss: 1.3327 - val_od_loss: 0.6901 - val_cup_loss: 0.6425 - val_od_accuracy: 0.5410 - val_cup_accuracy: 0.9784
# Epoch 6/100
# 2/2 [==============================] - 28s 19s/step - loss: 1.6988 - od_loss: 0.8341 - cup_loss: 0.8646 - od_accuracy: 0.5722 - cup_accuracy: 0.5511 - val_loss: 1.3168 - val_od_loss: 0.6805 - val_cup_loss: 0.6363 - val_od_accuracy: 0.7135 - val_cup_accuracy: 0.9797
# Epoch 7/100
# 2/2 [==============================] - 35s 22s/step - loss: 1.6734 - od_loss: 0.7958 - cup_loss: 0.8776 - od_accuracy: 0.5990 - cup_accuracy: 0.5338 - val_loss: 1.2983 - val_od_loss: 0.6695 - val_cup_loss: 0.6288 - val_od_accuracy: 0.8530 - val_cup_accuracy: 0.9802
# Epoch 8/100
# 2/2 [==============================] - 38s 29s/step - loss: 1.5658 - od_loss: 0.7308 - cup_loss: 0.8350 - od_accuracy: 0.6287 - cup_accuracy: 0.6112 - val_loss: 1.2800 - val_od_loss: 0.6579 - val_cup_loss: 0.6222 - val_od_accuracy: 0.9315 - val_cup_accuracy: 0.9803
# Epoch 9/100
# 2/2 [==============================] - 27s 20s/step - loss: 1.6357 - od_loss: 0.8308 - cup_loss: 0.8049 - od_accuracy: 0.5705 - cup_accuracy: 0.6011 - val_loss: 1.2585 - val_od_loss: 0.6437 - val_cup_loss: 0.6148 - val_od_accuracy: 0.9687 - val_cup_accuracy: 0.9801
# Epoch 10/100
# 2/2 [==============================] - 27s 20s/step - loss: 1.5638 - od_loss: 0.7820 - cup_loss: 0.7818 - od_accuracy: 0.5696 - cup_accuracy: 0.6101 - val_loss: 1.2394 - val_od_loss: 0.6302 - val_cup_loss: 0.6091 - val_od_accuracy: 0.9721 - val_cup_accuracy: 0.9800
# Epoch 11/100
# 2/2 [==============================] - 28s 20s/step - loss: 1.4150 - od_loss: 0.7141 - cup_loss: 0.7009 - od_accuracy: 0.6242 - cup_accuracy: 0.6444 - val_loss: 1.2235 - val_od_loss: 0.6209 - val_cup_loss: 0.6026 - val_od_accuracy: 0.9698 - val_cup_accuracy: 0.9799
# Epoch 12/100
# 2/2 [==============================] - 38s 29s/step - loss: 1.5614 - od_loss: 0.7407 - cup_loss: 0.8207 - od_accuracy: 0.6473 - cup_accuracy: 0.5925 - val_loss: 1.2093 - val_od_loss: 0.6133 - val_cup_loss: 0.5961 - val_od_accuracy: 0.9680 - val_cup_accuracy: 0.9797
# Epoch 13/100
# 2/2 [==============================] - 28s 19s/step - loss: 1.5249 - od_loss: 0.7454 - cup_loss: 0.7795 - od_accuracy: 0.6866 - cup_accuracy: 0.5730 - val_loss: 1.1950 - val_od_loss: 0.6052 - val_cup_loss: 0.5898 - val_od_accuracy: 0.9670 - val_cup_accuracy: 0.9795
# Epoch 14/100
# 2/2 [==============================] - 27s 20s/step - loss: 1.4971 - od_loss: 0.6576 - cup_loss: 0.8394 - od_accuracy: 0.7172 - cup_accuracy: 0.5404 - val_loss: 1.1802 - val_od_loss: 0.5974 - val_cup_loss: 0.5828 - val_od_accuracy: 0.9666 - val_cup_accuracy: 0.9794
# Epoch 15/100
# 2/2 [==============================] - 25s 17s/step - loss: 1.5244 - od_loss: 0.7656 - cup_loss: 0.7588 - od_accuracy: 0.6511 - cup_accuracy: 0.5992 - val_loss: 1.1657 - val_od_loss: 0.5891 - val_cup_loss: 0.5766 - val_od_accuracy: 0.9664 - val_cup_accuracy: 0.9793
# Epoch 16/100
# 2/2 [==============================] - 27s 20s/step - loss: 1.4627 - od_loss: 0.6978 - cup_loss: 0.7649 - od_accuracy: 0.6819 - cup_accuracy: 0.6074 - val_loss: 1.1508 - val_od_loss: 0.5803 - val_cup_loss: 0.5705 - val_od_accuracy: 0.9664 - val_cup_accuracy: 0.9793
# Epoch 17/100
# 2/2 [==============================] - 27s 20s/step - loss: 1.4049 - od_loss: 0.6446 - cup_loss: 0.7603 - od_accuracy: 0.7277 - cup_accuracy: 0.6021 - val_loss: 1.1373 - val_od_loss: 0.5724 - val_cup_loss: 0.5649 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9792
# Epoch 18/100
# 2/2 [==============================] - 29s 21s/step - loss: 1.6202 - od_loss: 0.7896 - cup_loss: 0.8306 - od_accuracy: 0.6295 - cup_accuracy: 0.5974 - val_loss: 1.1251 - val_od_loss: 0.5653 - val_cup_loss: 0.5597 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9791
# Epoch 19/100
# 2/2 [==============================] - 27s 20s/step - loss: 1.4468 - od_loss: 0.6756 - cup_loss: 0.7712 - od_accuracy: 0.7281 - cup_accuracy: 0.6119 - val_loss: 1.1137 - val_od_loss: 0.5591 - val_cup_loss: 0.5546 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9791
# Epoch 20/100
# 2/2 [==============================] - 28s 20s/step - loss: 1.5001 - od_loss: 0.7507 - cup_loss: 0.7493 - od_accuracy: 0.6862 - cup_accuracy: 0.6315 - val_loss: 1.1030 - val_od_loss: 0.5530 - val_cup_loss: 0.5500 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9791
# Epoch 21/100
# 2/2 [==============================] - 28s 19s/step - loss: 1.4013 - od_loss: 0.6512 - cup_loss: 0.7501 - od_accuracy: 0.7519 - cup_accuracy: 0.6296 - val_loss: 1.0924 - val_od_loss: 0.5470 - val_cup_loss: 0.5455 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 22/100
# 2/2 [==============================] - 28s 18s/step - loss: 1.3594 - od_loss: 0.6814 - cup_loss: 0.6780 - od_accuracy: 0.7320 - cup_accuracy: 0.6943 - val_loss: 1.0813 - val_od_loss: 0.5407 - val_cup_loss: 0.5407 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 23/100
# 2/2 [==============================] - 27s 18s/step - loss: 1.4637 - od_loss: 0.7275 - cup_loss: 0.7362 - od_accuracy: 0.7045 - cup_accuracy: 0.6565 - val_loss: 1.0714 - val_od_loss: 0.5349 - val_cup_loss: 0.5365 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 24/100
# 2/2 [==============================] - 27s 20s/step - loss: 1.4403 - od_loss: 0.6734 - cup_loss: 0.7669 - od_accuracy: 0.7468 - cup_accuracy: 0.6020 - val_loss: 1.0611 - val_od_loss: 0.5291 - val_cup_loss: 0.5320 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 25/100
# 2/2 [==============================] - 27s 20s/step - loss: 1.3244 - od_loss: 0.6905 - cup_loss: 0.6339 - od_accuracy: 0.7385 - cup_accuracy: 0.7071 - val_loss: 1.0503 - val_od_loss: 0.5228 - val_cup_loss: 0.5275 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 26/100
# 2/2 [==============================] - 24s 17s/step - loss: 1.3389 - od_loss: 0.6932 - cup_loss: 0.6456 - od_accuracy: 0.7844 - cup_accuracy: 0.6865 - val_loss: 1.0413 - val_od_loss: 0.5186 - val_cup_loss: 0.5228 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 27/100
# 2/2 [==============================] - 27s 20s/step - loss: 1.2442 - od_loss: 0.6066 - cup_loss: 0.6375 - od_accuracy: 0.7691 - cup_accuracy: 0.7226 - val_loss: 1.0307 - val_od_loss: 0.5129 - val_cup_loss: 0.5178 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 28/100
# 2/2 [==============================] - 39s 31s/step - loss: 1.3040 - od_loss: 0.6460 - cup_loss: 0.6580 - od_accuracy: 0.7628 - cup_accuracy: 0.6717 - val_loss: 1.0218 - val_od_loss: 0.5082 - val_cup_loss: 0.5135 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 29/100
# 2/2 [==============================] - 38s 29s/step - loss: 1.3050 - od_loss: 0.6902 - cup_loss: 0.6148 - od_accuracy: 0.7403 - cup_accuracy: 0.7043 - val_loss: 1.0121 - val_od_loss: 0.5035 - val_cup_loss: 0.5086 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 30/100
# 2/2 [==============================] - 28s 20s/step - loss: 1.3388 - od_loss: 0.6593 - cup_loss: 0.6796 - od_accuracy: 0.7194 - cup_accuracy: 0.6752 - val_loss: 1.0026 - val_od_loss: 0.4983 - val_cup_loss: 0.5043 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 31/100
# 2/2 [==============================] - 25s 17s/step - loss: 1.3629 - od_loss: 0.6499 - cup_loss: 0.7130 - od_accuracy: 0.7380 - cup_accuracy: 0.6387 - val_loss: 0.9941 - val_od_loss: 0.4939 - val_cup_loss: 0.5002 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 32/100
# 2/2 [==============================] - 28s 19s/step - loss: 1.1747 - od_loss: 0.5548 - cup_loss: 0.6199 - od_accuracy: 0.8011 - cup_accuracy: 0.7612 - val_loss: 0.9853 - val_od_loss: 0.4897 - val_cup_loss: 0.4955 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 33/100
# 2/2 [==============================] - 27s 18s/step - loss: 1.2676 - od_loss: 0.6389 - cup_loss: 0.6287 - od_accuracy: 0.7389 - cup_accuracy: 0.7133 - val_loss: 0.9762 - val_od_loss: 0.4851 - val_cup_loss: 0.4911 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 34/100
# 2/2 [==============================] - 27s 18s/step - loss: 1.1459 - od_loss: 0.5916 - cup_loss: 0.5543 - od_accuracy: 0.8117 - cup_accuracy: 0.8036 - val_loss: 0.9674 - val_od_loss: 0.4800 - val_cup_loss: 0.4874 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 35/100
# 2/2 [==============================] - 27s 20s/step - loss: 1.2751 - od_loss: 0.6283 - cup_loss: 0.6467 - od_accuracy: 0.7968 - cup_accuracy: 0.7335 - val_loss: 0.9595 - val_od_loss: 0.4758 - val_cup_loss: 0.4837 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 36/100
# 2/2 [==============================] - 25s 18s/step - loss: 1.2499 - od_loss: 0.6299 - cup_loss: 0.6200 - od_accuracy: 0.7827 - cup_accuracy: 0.7533 - val_loss: 0.9522 - val_od_loss: 0.4727 - val_cup_loss: 0.4795 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 37/100
# 2/2 [==============================] - 28s 19s/step - loss: 1.2699 - od_loss: 0.6133 - cup_loss: 0.6566 - od_accuracy: 0.7675 - cup_accuracy: 0.7312 - val_loss: 0.9457 - val_od_loss: 0.4694 - val_cup_loss: 0.4762 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 38/100
# 2/2 [==============================] - 28s 20s/step - loss: 1.2213 - od_loss: 0.5894 - cup_loss: 0.6319 - od_accuracy: 0.7869 - cup_accuracy: 0.7128 - val_loss: 0.9401 - val_od_loss: 0.4664 - val_cup_loss: 0.4737 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 39/100
# 2/2 [==============================] - 31s 21s/step - loss: 1.3510 - od_loss: 0.6612 - cup_loss: 0.6898 - od_accuracy: 0.7520 - cup_accuracy: 0.6741 - val_loss: 0.9342 - val_od_loss: 0.4636 - val_cup_loss: 0.4705 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 40/100
# 2/2 [==============================] - 29s 19s/step - loss: 1.1771 - od_loss: 0.5518 - cup_loss: 0.6254 - od_accuracy: 0.8065 - cup_accuracy: 0.7325 - val_loss: 0.9269 - val_od_loss: 0.4593 - val_cup_loss: 0.4676 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 41/100
# 2/2 [==============================] - 30s 19s/step - loss: 1.2243 - od_loss: 0.5997 - cup_loss: 0.6246 - od_accuracy: 0.7815 - cup_accuracy: 0.7103 - val_loss: 0.9205 - val_od_loss: 0.4557 - val_cup_loss: 0.4648 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 42/100
# 2/2 [==============================] - 29s 19s/step - loss: 1.1491 - od_loss: 0.6044 - cup_loss: 0.5447 - od_accuracy: 0.7999 - cup_accuracy: 0.8235 - val_loss: 0.9141 - val_od_loss: 0.4522 - val_cup_loss: 0.4619 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 43/100
# 2/2 [==============================] - 40s 30s/step - loss: 1.1509 - od_loss: 0.5496 - cup_loss: 0.6013 - od_accuracy: 0.8554 - cup_accuracy: 0.7608 - val_loss: 0.9084 - val_od_loss: 0.4499 - val_cup_loss: 0.4585 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 44/100
# 2/2 [==============================] - 29s 20s/step - loss: 1.1282 - od_loss: 0.5879 - cup_loss: 0.5403 - od_accuracy: 0.8049 - cup_accuracy: 0.8072 - val_loss: 0.9012 - val_od_loss: 0.4465 - val_cup_loss: 0.4547 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 45/100
# 2/2 [==============================] - 29s 21s/step - loss: 1.1644 - od_loss: 0.5419 - cup_loss: 0.6226 - od_accuracy: 0.8404 - cup_accuracy: 0.7686 - val_loss: 0.8940 - val_od_loss: 0.4429 - val_cup_loss: 0.4511 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 46/100
# 2/2 [==============================] - 29s 20s/step - loss: 1.1819 - od_loss: 0.6304 - cup_loss: 0.5515 - od_accuracy: 0.8251 - cup_accuracy: 0.8221 - val_loss: 0.8876 - val_od_loss: 0.4404 - val_cup_loss: 0.4472 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 47/100
# 2/2 [==============================] - 29s 20s/step - loss: 1.1450 - od_loss: 0.5254 - cup_loss: 0.6195 - od_accuracy: 0.8732 - cup_accuracy: 0.7917 - val_loss: 0.8811 - val_od_loss: 0.4376 - val_cup_loss: 0.4435 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 48/100
# 2/2 [==============================] - 47s 33s/step - loss: 1.1360 - od_loss: 0.5395 - cup_loss: 0.5965 - od_accuracy: 0.8574 - cup_accuracy: 0.7941 - val_loss: 0.8733 - val_od_loss: 0.4340 - val_cup_loss: 0.4392 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 49/100
# 2/2 [==============================] - 32s 21s/step - loss: 1.0384 - od_loss: 0.5195 - cup_loss: 0.5190 - od_accuracy: 0.8596 - cup_accuracy: 0.8431 - val_loss: 0.8655 - val_od_loss: 0.4303 - val_cup_loss: 0.4352 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 50/100
# 2/2 [==============================] - 29s 19s/step - loss: 1.1025 - od_loss: 0.5257 - cup_loss: 0.5768 - od_accuracy: 0.8655 - cup_accuracy: 0.8258 - val_loss: 0.8576 - val_od_loss: 0.4266 - val_cup_loss: 0.4310 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 51/100
# 2/2 [==============================] - 29s 19s/step - loss: 1.0725 - od_loss: 0.5325 - cup_loss: 0.5400 - od_accuracy: 0.8926 - cup_accuracy: 0.8332 - val_loss: 0.8506 - val_od_loss: 0.4231 - val_cup_loss: 0.4275 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 52/100
# 2/2 [==============================] - 39s 30s/step - loss: 1.0502 - od_loss: 0.5161 - cup_loss: 0.5341 - od_accuracy: 0.8623 - cup_accuracy: 0.8632 - val_loss: 0.8432 - val_od_loss: 0.4196 - val_cup_loss: 0.4236 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 53/100
# 2/2 [==============================] - 39s 31s/step - loss: 1.0526 - od_loss: 0.5117 - cup_loss: 0.5410 - od_accuracy: 0.8813 - cup_accuracy: 0.8443 - val_loss: 0.8362 - val_od_loss: 0.4168 - val_cup_loss: 0.4195 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 54/100
# 2/2 [==============================] - 28s 21s/step - loss: 1.0371 - od_loss: 0.5007 - cup_loss: 0.5364 - od_accuracy: 0.9019 - cup_accuracy: 0.8514 - val_loss: 0.8297 - val_od_loss: 0.4138 - val_cup_loss: 0.4160 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 55/100
# 2/2 [==============================] - 30s 20s/step - loss: 1.0680 - od_loss: 0.5637 - cup_loss: 0.5043 - od_accuracy: 0.8747 - cup_accuracy: 0.8697 - val_loss: 0.8245 - val_od_loss: 0.4118 - val_cup_loss: 0.4128 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 56/100
# 2/2 [==============================] - 30s 20s/step - loss: 0.9568 - od_loss: 0.4607 - cup_loss: 0.4961 - od_accuracy: 0.9044 - cup_accuracy: 0.8448 - val_loss: 0.8187 - val_od_loss: 0.4093 - val_cup_loss: 0.4094 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 57/100
# 2/2 [==============================] - 29s 20s/step - loss: 1.0116 - od_loss: 0.4537 - cup_loss: 0.5580 - od_accuracy: 0.9242 - cup_accuracy: 0.8665 - val_loss: 0.8126 - val_od_loss: 0.4067 - val_cup_loss: 0.4059 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 58/100
# 2/2 [==============================] - 29s 19s/step - loss: 0.9624 - od_loss: 0.4766 - cup_loss: 0.4858 - od_accuracy: 0.8917 - cup_accuracy: 0.8839 - val_loss: 0.8063 - val_od_loss: 0.4041 - val_cup_loss: 0.4023 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 59/100
# 2/2 [==============================] - 28s 18s/step - loss: 1.0137 - od_loss: 0.5100 - cup_loss: 0.5037 - od_accuracy: 0.8646 - cup_accuracy: 0.8543 - val_loss: 0.7989 - val_od_loss: 0.4010 - val_cup_loss: 0.3980 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 60/100
# 2/2 [==============================] - 39s 30s/step - loss: 1.0025 - od_loss: 0.5030 - cup_loss: 0.4995 - od_accuracy: 0.8875 - cup_accuracy: 0.8364 - val_loss: 0.7912 - val_od_loss: 0.3973 - val_cup_loss: 0.3939 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 61/100
# 2/2 [==============================] - 30s 21s/step - loss: 0.9974 - od_loss: 0.4857 - cup_loss: 0.5118 - od_accuracy: 0.8952 - cup_accuracy: 0.8731 - val_loss: 0.7836 - val_od_loss: 0.3939 - val_cup_loss: 0.3897 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 62/100
# 2/2 [==============================] - 30s 20s/step - loss: 0.9612 - od_loss: 0.4803 - cup_loss: 0.4809 - od_accuracy: 0.9071 - cup_accuracy: 0.8649 - val_loss: 0.7752 - val_od_loss: 0.3898 - val_cup_loss: 0.3854 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 63/100
# 2/2 [==============================] - 40s 21s/step - loss: 0.8954 - od_loss: 0.4643 - cup_loss: 0.4311 - od_accuracy: 0.8948 - cup_accuracy: 0.9040 - val_loss: 0.7678 - val_od_loss: 0.3861 - val_cup_loss: 0.3817 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 64/100
# 2/2 [==============================] - 29s 20s/step - loss: 0.9791 - od_loss: 0.4618 - cup_loss: 0.5173 - od_accuracy: 0.9303 - cup_accuracy: 0.8777 - val_loss: 0.7612 - val_od_loss: 0.3831 - val_cup_loss: 0.3781 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 65/100
# 2/2 [==============================] - 28s 19s/step - loss: 0.9306 - od_loss: 0.4664 - cup_loss: 0.4642 - od_accuracy: 0.9123 - cup_accuracy: 0.8978 - val_loss: 0.7549 - val_od_loss: 0.3805 - val_cup_loss: 0.3744 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 66/100
# 2/2 [==============================] - 29s 19s/step - loss: 0.8919 - od_loss: 0.4233 - cup_loss: 0.4687 - od_accuracy: 0.9142 - cup_accuracy: 0.8853 - val_loss: 0.7481 - val_od_loss: 0.3774 - val_cup_loss: 0.3707 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 67/100
# 2/2 [==============================] - 30s 20s/step - loss: 0.9902 - od_loss: 0.4674 - cup_loss: 0.5229 - od_accuracy: 0.8490 - cup_accuracy: 0.8725 - val_loss: 0.7411 - val_od_loss: 0.3737 - val_cup_loss: 0.3674 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 68/100
# 2/2 [==============================] - 31s 20s/step - loss: 0.9209 - od_loss: 0.4724 - cup_loss: 0.4484 - od_accuracy: 0.8899 - cup_accuracy: 0.8820 - val_loss: 0.7353 - val_od_loss: 0.3710 - val_cup_loss: 0.3643 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 69/100
# 2/2 [==============================] - 39s 29s/step - loss: 0.9291 - od_loss: 0.4434 - cup_loss: 0.4857 - od_accuracy: 0.9274 - cup_accuracy: 0.9113 - val_loss: 0.7295 - val_od_loss: 0.3682 - val_cup_loss: 0.3613 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 70/100
# 2/2 [==============================] - 40s 31s/step - loss: 0.9206 - od_loss: 0.4330 - cup_loss: 0.4876 - od_accuracy: 0.9246 - cup_accuracy: 0.8983 - val_loss: 0.7231 - val_od_loss: 0.3650 - val_cup_loss: 0.3581 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 71/100
# 2/2 [==============================] - 30s 21s/step - loss: 0.9430 - od_loss: 0.5012 - cup_loss: 0.4418 - od_accuracy: 0.9103 - cup_accuracy: 0.9363 - val_loss: 0.7170 - val_od_loss: 0.3621 - val_cup_loss: 0.3549 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 72/100
# 2/2 [==============================] - 30s 21s/step - loss: 0.8454 - od_loss: 0.4096 - cup_loss: 0.4359 - od_accuracy: 0.9306 - cup_accuracy: 0.8771 - val_loss: 0.7104 - val_od_loss: 0.3590 - val_cup_loss: 0.3514 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 73/100
# 2/2 [==============================] - 30s 20s/step - loss: 0.8460 - od_loss: 0.4085 - cup_loss: 0.4376 - od_accuracy: 0.9338 - cup_accuracy: 0.8961 - val_loss: 0.7032 - val_od_loss: 0.3554 - val_cup_loss: 0.3478 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 74/100
# 2/2 [==============================] - 29s 19s/step - loss: 0.7793 - od_loss: 0.3754 - cup_loss: 0.4039 - od_accuracy: 0.9281 - cup_accuracy: 0.9305 - val_loss: 0.6958 - val_od_loss: 0.3515 - val_cup_loss: 0.3443 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 75/100
# 2/2 [==============================] - 28s 18s/step - loss: 0.8376 - od_loss: 0.4157 - cup_loss: 0.4219 - od_accuracy: 0.9275 - cup_accuracy: 0.9195 - val_loss: 0.6888 - val_od_loss: 0.3482 - val_cup_loss: 0.3406 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 76/100
# 2/2 [==============================] - 39s 29s/step - loss: 0.8218 - od_loss: 0.4321 - cup_loss: 0.3897 - od_accuracy: 0.9215 - cup_accuracy: 0.9445 - val_loss: 0.6811 - val_od_loss: 0.3445 - val_cup_loss: 0.3366 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 77/100
# 2/2 [==============================] - 29s 21s/step - loss: 0.8238 - od_loss: 0.3802 - cup_loss: 0.4436 - od_accuracy: 0.9253 - cup_accuracy: 0.9042 - val_loss: 0.6734 - val_od_loss: 0.3406 - val_cup_loss: 0.3328 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 78/100
# 2/2 [==============================] - 29s 20s/step - loss: 0.8319 - od_loss: 0.4168 - cup_loss: 0.4151 - od_accuracy: 0.9222 - cup_accuracy: 0.9072 - val_loss: 0.6667 - val_od_loss: 0.3373 - val_cup_loss: 0.3294 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 79/100
# 2/2 [==============================] - 30s 21s/step - loss: 0.8198 - od_loss: 0.4223 - cup_loss: 0.3975 - od_accuracy: 0.9299 - cup_accuracy: 0.9300 - val_loss: 0.6606 - val_od_loss: 0.3345 - val_cup_loss: 0.3262 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 80/100
# 2/2 [==============================] - 41s 32s/step - loss: 0.8022 - od_loss: 0.3895 - cup_loss: 0.4126 - od_accuracy: 0.9359 - cup_accuracy: 0.9487 - val_loss: 0.6544 - val_od_loss: 0.3313 - val_cup_loss: 0.3231 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 81/100
# 2/2 [==============================] - 32s 21s/step - loss: 0.8020 - od_loss: 0.4068 - cup_loss: 0.3952 - od_accuracy: 0.9325 - cup_accuracy: 0.9203 - val_loss: 0.6480 - val_od_loss: 0.3281 - val_cup_loss: 0.3198 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 82/100
# 2/2 [==============================] - 29s 19s/step - loss: 0.7536 - od_loss: 0.3773 - cup_loss: 0.3763 - od_accuracy: 0.9340 - cup_accuracy: 0.9307 - val_loss: 0.6414 - val_od_loss: 0.3251 - val_cup_loss: 0.3163 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 83/100
# 2/2 [==============================] - 39s 29s/step - loss: 0.8363 - od_loss: 0.4161 - cup_loss: 0.4203 - od_accuracy: 0.9172 - cup_accuracy: 0.9180 - val_loss: 0.6344 - val_od_loss: 0.3223 - val_cup_loss: 0.3121 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 84/100
# 2/2 [==============================] - 39s 30s/step - loss: 0.8524 - od_loss: 0.4504 - cup_loss: 0.4020 - od_accuracy: 0.8980 - cup_accuracy: 0.9074 - val_loss: 0.6277 - val_od_loss: 0.3203 - val_cup_loss: 0.3074 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 85/100
# 2/2 [==============================] - 29s 20s/step - loss: 0.7435 - od_loss: 0.3878 - cup_loss: 0.3557 - od_accuracy: 0.9430 - cup_accuracy: 0.9428 - val_loss: 0.6208 - val_od_loss: 0.3181 - val_cup_loss: 0.3027 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 86/100
# 2/2 [==============================] - 27s 18s/step - loss: 0.8424 - od_loss: 0.4101 - cup_loss: 0.4322 - od_accuracy: 0.9241 - cup_accuracy: 0.9244 - val_loss: 0.6147 - val_od_loss: 0.3161 - val_cup_loss: 0.2986 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 87/100
# 2/2 [==============================] - 29s 20s/step - loss: 0.7454 - od_loss: 0.3929 - cup_loss: 0.3525 - od_accuracy: 0.9268 - cup_accuracy: 0.9547 - val_loss: 0.6087 - val_od_loss: 0.3139 - val_cup_loss: 0.2948 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 88/100
# 2/2 [==============================] - 30s 21s/step - loss: 0.7510 - od_loss: 0.3874 - cup_loss: 0.3636 - od_accuracy: 0.9328 - cup_accuracy: 0.9572 - val_loss: 0.6038 - val_od_loss: 0.3127 - val_cup_loss: 0.2911 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 89/100
# 2/2 [==============================] - 29s 20s/step - loss: 0.7655 - od_loss: 0.3777 - cup_loss: 0.3877 - od_accuracy: 0.9452 - cup_accuracy: 0.9426 - val_loss: 0.5991 - val_od_loss: 0.3110 - val_cup_loss: 0.2881 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 90/100
# 2/2 [==============================] - 28s 18s/step - loss: 0.7586 - od_loss: 0.3808 - cup_loss: 0.3777 - od_accuracy: 0.9132 - cup_accuracy: 0.9482 - val_loss: 0.5953 - val_od_loss: 0.3093 - val_cup_loss: 0.2859 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 91/100
# 2/2 [==============================] - 30s 20s/step - loss: 0.7622 - od_loss: 0.3888 - cup_loss: 0.3734 - od_accuracy: 0.9305 - cup_accuracy: 0.9512 - val_loss: 0.5914 - val_od_loss: 0.3077 - val_cup_loss: 0.2838 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 92/100
# 2/2 [==============================] - 30s 21s/step - loss: 0.7311 - od_loss: 0.3449 - cup_loss: 0.3862 - od_accuracy: 0.9486 - cup_accuracy: 0.9481 - val_loss: 0.5873 - val_od_loss: 0.3059 - val_cup_loss: 0.2814 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 93/100
# 2/2 [==============================] - 31s 20s/step - loss: 0.7124 - od_loss: 0.3645 - cup_loss: 0.3479 - od_accuracy: 0.9345 - cup_accuracy: 0.9446 - val_loss: 0.5828 - val_od_loss: 0.3038 - val_cup_loss: 0.2790 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 94/100
# 2/2 [==============================] - 29s 19s/step - loss: 0.7237 - od_loss: 0.3693 - cup_loss: 0.3545 - od_accuracy: 0.9356 - cup_accuracy: 0.9554 - val_loss: 0.5784 - val_od_loss: 0.3016 - val_cup_loss: 0.2768 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 95/100
# 2/2 [==============================] - 40s 29s/step - loss: 0.7254 - od_loss: 0.3625 - cup_loss: 0.3629 - od_accuracy: 0.9297 - cup_accuracy: 0.9551 - val_loss: 0.5737 - val_od_loss: 0.2992 - val_cup_loss: 0.2746 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 96/100
# 2/2 [==============================] - 39s 30s/step - loss: 0.6556 - od_loss: 0.3106 - cup_loss: 0.3450 - od_accuracy: 0.9490 - cup_accuracy: 0.9641 - val_loss: 0.5686 - val_od_loss: 0.2963 - val_cup_loss: 0.2723 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 97/100
# 2/2 [==============================] - 28s 20s/step - loss: 0.6969 - od_loss: 0.3333 - cup_loss: 0.3635 - od_accuracy: 0.9435 - cup_accuracy: 0.9460 - val_loss: 0.5632 - val_od_loss: 0.2934 - val_cup_loss: 0.2698 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 98/100
# 2/2 [==============================] - 27s 19s/step - loss: 0.6563 - od_loss: 0.3261 - cup_loss: 0.3301 - od_accuracy: 0.9512 - cup_accuracy: 0.9676 - val_loss: 0.5577 - val_od_loss: 0.2904 - val_cup_loss: 0.2673 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 99/100
# 2/2 [==============================] - 31s 21s/step - loss: 0.6449 - od_loss: 0.3175 - cup_loss: 0.3274 - od_accuracy: 0.9469 - cup_accuracy: 0.9610 - val_loss: 0.5526 - val_od_loss: 0.2875 - val_cup_loss: 0.2650 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790
# Epoch 100/100
# 2/2 [==============================] - 31s 20s/step - loss: 0.6227 - od_loss: 0.3086 - cup_loss: 0.3141 - od_accuracy: 0.9400 - cup_accuracy: 0.9701 - val_loss: 0.5472 - val_od_loss: 0.2845 - val_cup_loss: 0.2627 - val_od_accuracy: 0.9663 - val_cup_accuracy: 0.9790

# %%
def plot_loss(epochs, hist, loss):
    '''
    Shows the loss metrics
    Uses a more fair comparison
    Between Val and Train
    By shifting the train loss
    an epoch later
    (Train loss is also hurt
    by the dropout layers)
    '''
    plt.plot(epochs + .5, hist.history['loss'], 'r', label = 'Loss')
    plt.plot(epochs + .5, hist.history['od_loss'], 'r.-', label = 'OD Loss')
    plt.plot(epochs + .5, hist.history['cup_loss'], 'r+', label = 'Cup Loss')
    plt.plot(epochs, hist.history['val_loss'], 'b', label = 'Val Loss')
    plt.plot(epochs, hist.history['val_od_loss'], 'b.-', label = 'Val OD Loss')
    plt.plot(epochs, hist.history['val_cup_loss'], 'b+', label = 'Val Cup Loss')
    plt.legend()
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title(loss)


epochs1 = np.arange(0, len(hist1.history['loss']))
plot_loss(epochs1, hist1, 'Dice')

# %%
epochs2 = np.arange(0, len(hist2.history['loss']))
plot_loss(epochs2, hist2, 'Binary CrossEntropy')

# %%
to_predict = Dataset.from_tensor_slices(test_images)\
    .map(lambda x: load_image_with_masks(x, dice = True, test = True), num_parallel_calls = AUTOTUNE)\
    .map(lambda image, targets: image['image'])\
    .batch(batch_size = BATCH_SIZE)


predict1 = mod1.predict(to_predict)
predict2 = mod2.predict(to_predict)
# Out:
# 3/3 [==============================] - 12s 2s/step
# 3/3 [==============================] - 17s 2s/step

# %%
test = next(iter(predict1))
test.shape
# Out:
# (51, 224, 224, 1)

# %%
def plt_preds(ds, preds, super_title, binarizer_threshold = 0.5):
    '''
    Plots row numbers of images
    Along with the original mask
    And the predicted mask
    Also binarizes the predicted
    masks
    '''
    ds = next(iter(ds))
    image, targets = ds
    image = image['image']
    od = targets['od']
    cup = targets['cup']
    preds = next(iter(preds))
    rows = 5
    cols = 7
    fig, axes = plt.subplots(rows, cols, figsize = (20, 20))
    axes = axes.flatten()
    for i in range(rows):
        axes[cols * i].imshow(image[i])
        axes[cols * i].set_title('Original Image')
        axes[cols * i + 1].imshow(od[i])
        axes[cols * i + 1].set_title('Original OD Mask')
        axes[cols * i + 2].imshow(cup[i])
        axes[cols * i + 2].set_title('Original Cup Mask')
        axes[cols * i + 3].imshow(preds[i])
        axes[cols * i + 3].set_title('Predicted OD Mask')
        axes[cols * i + 4].imshow(np.where(preds[i] > binarizer_threshold, 1, 0))
        axes[cols * i + 4].set_title('Binarized OD Mask')
        axes[cols * i + 5].imshow(preds[26 + i - 1])
        axes[cols * i + 5].set_title('Predicted Cup Mask')
        axes[cols * i + 6].imshow(np.where(preds[26 + i] >= binarizer_threshold, 1, 0))
        axes[cols * i + 6].set_title('Binarized Cup Mask')
    plt.suptitle(super_title)

# %%
plt_preds(test_ds_dice, predict1, super_title = 'Dice Loss Trained on Binarized GT Masks', binarizer_threshold = 0.5)

# %%
plt_preds(test_ds_no_dice, predict2, binarizer_threshold = 0.25, super_title = 'Binary Cross Entropy Trained on Default Masks')
